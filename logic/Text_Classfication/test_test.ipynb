# %%
import gensim
from konlpy.tag import Twitter

# %%
pos_in = ['Noun','Adjective','Verb']#,'Number','URL','Alpha', 'Adjective', 'Suffix', 'Hashtag', 'Alpha', 'Unknown', 'Eomi', 'Foreign'
tagged = []
sentence = []

# %%
#고통
sentence.append(("매일매일 너무 스트레스 받아서 힘들고 고통스럽습니다. 이럴 땐 어떻게 해야 하나요?","고통"))
sentence.append(("삶이 힘들고 고통스러워요, 하루에도 몇번씩 죽고싶다는 생각이 듭니다 어떻게 해야하나요?","고통"))
sentence.append(("힘든 고통속에서 허우적거리고 있는데 어떻게 해야 하나요?","고통"))
sentence.append(("갑자기 우울해지고 살기가 어려워 졌습니다. 이런 고통속에서는 어떻게 살아내야하나요?","고통"))
sentence.append(("세상에 고통은 왜 존재하는 것인가요? 고통이 주는 의미는 무엇인가요?","고통"))
sentence.append(("하나님을 믿어도 고통이 면재가 되질 않습니다. 너무 힘들고 어려운데 이럴 땐 어떻게 해야 하나요?","고통"))
sentence.append(("마음의 고통으로 힘들어 하고 있습니다. 이 마음의 고통을 덜어내려면 어떻게 해야 하나요?","고통"))
sentence.append(("지금 육체적인 고통에 시달리고 있습니다. 허리가 너무 아파서 어딜 나가지를 못합니다. 이럴 땐 어떻게 해야하나요?","고통"))
sentence.append(("제 인생은 고통뿐인 인생입니다. 제 인생의 고통을 해결하려면 어떻게 해야하나요?","고통"))
sentence.append(("살면서 감당할 수 없는 고난에 마주했습니다. 이 고난을 어떻게 피해갈 수 있을까요?","고통"))
#건강
sentence.append(("제가 허리건강이 너무 안좋습니다. 건강해지려면 어떻게 해야 하나요?","건강"))
sentence.append(("건강하게 지내고 싶습니다. 어떻게 하면 건강해질 수 있나요?","건강"))
sentence.append(("제가 장이 안좋아서 매일 속이 더부룩합니다. 몸이 건강해지려면 어떻게 해야하나요?","건강"))
sentence.append(("내 몸의 건강을 유지하는 방법이 있을까요?","건강"))
sentence.append(("환절기에 건강 관리하는 방법을 알려주세요.","건강"))
sentence.append(("제가 나이가 많은데 건강해지고 싶습니다. 건강해지려면 어떻게 해야하나요?","건강"))
sentence.append(("몸이 약한 것 같아서 건강 관리를 좀 하려고 합니다. 어떻게 하면 좋을까요?","건강"))
sentence.append(("여름에 건강하게 지내려면 어떻게 해야 하나요? 알려주세요","건강"))
sentence.append(("암 안걸리고 건강하게 살고 싶습니다. 건강해지려면 어떻게 해야 하나요?","건강"))
sentence.append(("병에 걸려서 고생중입니다. 어떻게 하면 병이 낫고 건강해 질 수 있나요?","건강"))
#연애
sentence.append(("지금 만난 남자친구와 결혼해도 괜찮을까요?","연애"))
sentence.append(("연애하고 싶은데 어떤 사람을 만나야하나요? 궁금합니다.","연애"))
sentence.append(("연애한지 4년이 지났는데 한 번도 싸운적이 없습니다. 이 사람과 결혼해도 괜찮을까요?","연애"))
sentence.append(("결혼하고 싶은데 어떤 사람을 만나서 결혼해야하나요?","연애"))
sentence.append(("지금 좋아하는 사람이 있는데 고백해도 될까요? 이 사람과 결혼하고 싶어요.","연애"))
sentence.append(("제가 좋아하는 사람과 저를 좋아하는 사람 둘 중에 어떤 사람을 만나야 하나요?","연애"))
sentence.append(("오랜기간 만나서 정도 많이 들고 추억도 많이 쌓인 연인이랑 결혼해도 괜찮을까요?","연애"))
sentence.append(("제가 벌이가 좋지는 않은데 결혼하고 싶습니다. 결혼해도 괜찮을까요?","연애"))
sentence.append(("결혼 상대는 어떻게 결정해야하나요?","연애"))
sentence.append(("어떤 사람과 연애하고 결혼해야하나요? 좋은사람은 어떤 사람인가요?","연애"))
#게으름
sentence.append(("어느 순간 나태함과 게으름으로 문제가 발생하고 있습니다.","게으름"))
sentence.append(("나태, 태만, 게으름을 고칠수있는 방법좀 알려주세요","게으름"))
sentence.append(("전 진짜로 게을러서 어렸을 때부터 집에서는 커녕 학원에서 2시간도 공부하지 못했습니다.","게으름"))
sentence.append(("점점 제가 나태해진것 같아요. 의욕이 없어졌죠. 의욕이 생기더라도 몇일 지나면 사그라졌어요 지금 벌써 3주 지났습니다","게으름"))
sentence.append(("대학생이 되니까 사람이 게으르고 나태해지는 걸 느낍니다. 어떻게 하면 사람이 좀 더 부지런해질 수 있을까요?","게으름"))
sentence.append(("게으름에서 벗어난 경험자분들의 조언이 필요합니다.","게으름"))
sentence.append(("제 자신이 너무 게을러서 싫습니다. 해야할 공부도 많고 읽을 책도 많은데 오히려 많아서인지 부담감 때문에 그냥 다 놓아버리고 싶어요.","게으름"))
sentence.append(("게으름과 나태함으로 귀찮음을 느끼고 아무것도 안하는 제가 참 한심할 따름입니다. 어떻게 하면 게으름과 나태함을 고칠 수 있을까요?","게으름"))
sentence.append(("저의 게으름과 모든걸 귀찮아하는 나태함을 치유할 방법이 없을까요","게으름"))
sentence.append(("매일 침대에서 일어나기가 싫습니다. 많이 게을러지고 나태해진 것 같습니다.","게으름"))
#겸손
sentence.append(("겸손한 마음을 가지려면 어떻게해야되나요? 겸손하다의 뜻이 뭔가요?","겸손"))
sentence.append(("겸손 해지고 싶어요. 아직은 가진게 넉넉하지 않고 앞서 내세울 만큼 잘난 구석도 없구요. 보잘것 없고  부족 하지만 이 한몸 겸손한 맘으로 하나님만을 바라보며 늘 감사한 마음으로 살고 싶어요.","겸손"))
sentence.append(("어떻게하면 좀 더 현명한 겸손한 사람이 될수 있을까요? 어떻게하면 남의 의견과 분야를 존중할수 있을까요?","겸손"))
sentence.append(("마음이 교만해질때 묵상할 수 있는 가장 좋은 말씀 좀 부탁합니다.","겸손"))
sentence.append(("진정한 겸손이란 무엇인가요?","겸손"))
sentence.append(("겸손은 말로 들으면 참 실천하기 좋은것 같아요 근데 막상하면 실천의지가 부족해서인지 너무 자만하는거같아요 겸손해지법좀 알려주세요","겸손"))
sentence.append(("자만하지 않으려면 어떻게 해야하나요?  저는 자만해서 방심하다가 낭패를 자주 봅니다.","겸손"))
sentence.append(("착한 척 하는 사람이 아니라,  겸손한 척 하는 사람이 아니라  정말로 뼛 속까지 겸손한 사람이 되고 싶어요.","겸손"))
sentence.append(("교만하지 않고 마음이 겸손한 사람이 되고 싶은데 어떻게 해야 하나요?","겸손"))
sentence.append(("다른 사람을 존중하는 겸손한 사람이 되고 싶습니다. 교만을 버리고 싶습니다.","겸손"))
#기도
sentence.append(("기도를 하는법은 어떻게 되나요?","기도"))
sentence.append(("제가 교회를 다니는데 저만 방언을 안해서요 제가 평소에 기도도 잘 안해서 일까요?","기도"))
sentence.append(("교회를 다닌지 조금 오래 되지만 아직도 기도 하는 법를 잘 몰라서요. 기도는 어떻게 해야 하나요?","기도"))
sentence.append(("기도를 하고 싶은데 어떤 내용으로 기도를 해야하나요? 기도하면 응답을 받을 수 있나요?","기도"))
sentence.append(("기도할 때 구체적으로 무엇을 기도해야하는지 잘 모르겠습니다. 무엇에 대해서 기도해야하나요?","기도"))
sentence.append(("마음이 너무 복잡해서 기도가 되지 않습니다. 이럴 땐 어떻게 해야 하나요?","기도"))
sentence.append(("기도가 너무 어렵게 느껴지는데 기도는 어떻게 하는 건가요?","기도"))
sentence.append(("누군가를 위해서 기도하려는데 어떻게 기도해야하나요?","기도"))
sentence.append(("기도하는 것이 익숙하지 않고 교회를 다니지 않아서 기도하는 방법을 모르는데, 기도는 어떻게 하는 건가요?","기도"))
sentence.append(("기도에 집중이 잘 안되고 기도하면서 무슨 말을 해야하는지 잘 모르겠어요. 기도하는 방법에 대해서 알려주세요.","기도"))
#걱정
sentence.append(("요즘 세상걱정에 잠을 못이루고 있습니다. 이런 저런 불안이 찾아오면서 너무 힘드네요.","걱정"))
sentence.append(("걱정이 너무 많아서 일이 손에 안잡힙니다. 틈만나면 이런 걱정 저런 걱정이 드는데 어떻게 하면 좋을까요?","걱정"))
sentence.append(("요즘들어서 쓸데없는 걱정을 많이 해서 힘듭니다. 너무 생각이 많습니다. 도대체 어떻게 해야 쓸데없는 생각들을 안할 수 있을까요?","걱정"))
sentence.append(("제가 돈이 없어서 생활걱정에 시달리고 있습니다. 생활비에 대한 걱정을 안하려면 어떻게 해야 할까요?","걱정"))
sentence.append(("평소에 쓸데없는 걱정이 너무 많아서 힘듭니다. 걱정을 안하고 싶은데 어떻게 해야 할까요?","걱정"))
sentence.append(("일어나지도 않을 일들에 대해서 걱정도 되고 불안함에 두려움을 느끼기도 합니다. 어떻게 하면 두려움을 없앨 수 있을까요?","걱정"))
sentence.append(("제가 평소에 걱정과 염려가 많아서 일어나지도 않을 일에 두려움을 많이 느끼는데 어떻게 하면 좋을까요?","걱정"))
sentence.append(("걱정과 염려 때문에 힘듭니다. 어떻게 하면 걱정과 염려를 안할 수 있나요?","걱정"))
sentence.append(("계속 혼자 생각하고 걱정하고 불안해하고 하는데 어떻게 하면 염려를 없애고 두려워 하지 않을 수 있나요?","걱정"))
sentence.append(("기독교에서는 미래에 대한 걱정, 근심, 불안, 두려움이 있을때 어떻게 하나요?","걱정"))
#죄
sentence.append(("자꾸 지었던 죄를 반복해서 짓게 됩니다. 어떻게 하면 죄를 안지을 수 있나요?","죄"))
sentence.append(("제 동생이 죄를 지었습니다. 계속 반복해서 죄를 짓는데 어떻게 하면 좋나요?","죄"))
sentence.append(("사회가 점점 악해지고 범죄가 넘쳐나고 있습니다. 이 사회는 어떻게 죄에서 빠져 나올 수 있나요?","죄"))
sentence.append(("죄를 짓고 싶지 않은데 계속해서 죄를 짓게 됩니다. 어떻게 하면 좋을까요? 죄를 지었을 때는 어떻게 해야 하나요?","죄"))
sentence.append(("형제가 죄를 범한 것을 어떻게 하면 좋을까요? 죄를 용서해 주어야 하나요?","죄"))
sentence.append(("자매가 자꾸 죄를 짓는데 어떻게 하면 좋을까요? 죄를 지은 대가를 치르게 해야 하나요?","죄"))
sentence.append(("죄에서 벗어나고 싶은데 쉽지가 않습니다. 어떻게 하면 죄에서 벗어날 수 있나요? 죄를 짓지 않으려면 어떻게 살아야 하나요?","죄"))
sentence.append(("이 사회와 국가가 죄에 빠져 있는데 어떻게 하면 좋나요? 죄에서 자유를 얻게 하려면 어떻게 해야 할까요?","죄"))
sentence.append(("죄를 너무 많이 지었는데 저는 어떻게 되는 건가요? 죄를 해결 받기 위해서는 어떻게 해야 하나요?","죄"))
sentence.append(("죄를 범한사람을 어떻게 하면 좋을까요? 죄를 용서해줘야 할까요? 아니면 엄벌에 처해야 할까요?","죄"))
#일
sentence.append(("일하면서 너무 지치고 힘들어요. 일하면서 일과 휴식의 균형은 어떻게 맞춰야 하나요?","일"))
sentence.append(("요새 일이 너무 바빠지면서 정신이 하나도 없습니다. 일을 이렇게 바쁘게만 하는게 맞나요?","일"))
sentence.append(("요새 일이 많아지면서 신앙이 뒷전이 되어가고 있습니다. 일과 신앙의 균형을 어떻게 맞춰야 하나요?","일"))
sentence.append(("일도 열심히 하고 신앙 생활도 열심히 하고 싶습니다. 어떻게 해야 하나요?","일"))
sentence.append(("일은 열심히 하려고 하는데 일에 성과가 나타나지 않습니다. 어떻게 하면 일의 성과를 만들 수 있나요?","일"))
sentence.append(("이제 곧 취업을 해야 하는데 어떤 직장에 다니는게 좋을까요? 또 어떤 마음가짐으로 직장에 임해야 할까요?","일"))
sentence.append(("이제 직장을 구해야 하는데 어떤 일을 해야할 지 잘 모르겠습니다. 어떤 직장을 선택하면 좋을까요?","일"))
sentence.append(("직장에서 일을 하는데 성과가 안나와서 매일 욕먹습니다. 어떻게 하면 좋은 결과를 얻어낼 수 있을까요?","일"))
sentence.append(("매일 일에 치이다보니 쉴 틈이 없습니다. 어떻게 하면 일과 쉼의 균형을 맞추어 갈 수 있나요?","일"))
sentence.append(("일을 열심히 하려하면 자꾸 신앙생활을 소홀히 하게 됩니다. 어떻게 하면 일과 신앙의 균형을 잘 맞출 수 있나요?","일"))
#진리
sentence.append(("진리는 무엇인가요? 어떻게 하면 진리에 대해서 알게 되나요?","진리"))
sentence.append(("진리에 대해서 알고 싶은데 어떻게 하면 알 수 있나요?","진리"))
sentence.append(("인생의 진리는 무엇일까요? 정말로 궁금합니다.","진리"))
sentence.append(("도대체 진리는 무엇인가요? 진리에 대해서 알고 싶습니다.","진리"))
sentence.append(("인생의 진리는 어디에 있나요? 진리를 깨닫게 되려면 어떻게 해야 하나요?","진리"))
sentence.append(("진리는 무엇인가요? 진리에 대해서 궁금함이 생겼는데 꼭 알고 싶습니다.","진리"))
sentence.append(("인생의 진리는 어디에서 찾을 수 있나요? 구체적으로 알려주세요.","진리"))
sentence.append(("모든것의 참 진리는 도대체 무엇인가요? 진리가 이 세상에 존재하기는 한 것인가요?","진리"))
sentence.append(("진리에 대해서 알고 싶습니다. 진리란 무엇인가요?","진리"))
sentence.append(("다들 진리에 대해서 얘기하는데 도대체 참 진리는 무엇인가요? 인생의 진리는 존재하는 것인가요?","진리"))

# %%
user_input = "인생이 너무 힘들고 고통스럽습니다. 고통속에서 매일매일 살고 있는데 어떻게 해야 하나요?"
#user_input = "결혼하고 싶습니다. 연애하고 싶습니다."
#user_input = "병에 걸려서 몸이 많이 좋지 않습니다. 병이 나으려면 어떻게 해야 하나요?"
#user_input = "요즘 걱정때문에 잠을 잘 못이룹니다. 걱정과 염려로 인해서 불안함이 느껴지네요."
#user_input = "기도하는 방법을 알고 싶어요. 기도는 어떻게 하는건가요?"
sentence.append((user_input,"고민"))

# %%
sentence
# Out:
# [('매일매일 너무 스트레스 받아서 힘들고 고통스럽습니다. 이럴 땐 어떻게 해야 하나요?', '고통'),
#  ('삶이 힘들고 고통스러워요, 하루에도 몇번씩 죽고싶다는 생각이 듭니다 어떻게 해야하나요?', '고통'),
#  ('힘든 고통속에서 허우적거리고 있는데 어떻게 해야 하나요?', '고통'),
#  ('갑자기 우울해지고 살기가 어려워 졌습니다. 이런 고통속에서는 어떻게 살아내야하나요?', '고통'),
#  ('세상에 고통은 왜 존재하는 것인가요? 고통이 주는 의미는 무엇인가요?', '고통'),
#  ('하나님을 믿어도 고통이 면재가 되질 않습니다. 너무 힘들고 어려운데 이럴 땐 어떻게 해야 하나요?', '고통'),
#  ('마음의 고통으로 힘들어 하고 있습니다. 이 마음의 고통을 덜어내려면 어떻게 해야 하나요?', '고통'),
#  ('지금 육체적인 고통에 시달리고 있습니다. 허리가 너무 아파서 어딜 나가지를 못합니다. 이럴 땐 어떻게 해야하나요?', '고통'),
#  ('제 인생은 고통뿐인 인생입니다. 제 인생의 고통을 해결하려면 어떻게 해야하나요?', '고통'),
#  ('살면서 감당할 수 없는 고난에 마주했습니다. 이 고난을 어떻게 피해갈 수 있을까요?', '고통'),
#  ('제가 허리건강이 너무 안좋습니다. 건강해지려면 어떻게 해야 하나요?', '건강'),
#  ('건강하게 지내고 싶습니다. 어떻게 하면 건강해질 수 있나요?', '건강'),
#  ('제가 장이 안좋아서 매일 속이 더부룩합니다. 몸이 건강해지려면 어떻게 해야하나요?', '건강'),
#  ('내 몸의 건강을 유지하는 방법이 있을까요?', '건강'),
#  ('환절기에 건강 관리하는 방법을 알려주세요.', '건강'),
#  ('제가 나이가 많은데 건강해지고 싶습니다. 건강해지려면 어떻게 해야하나요?', '건강'),
#  ('몸이 약한 것 같아서 건강 관리를 좀 하려고 합니다. 어떻게 하면 좋을까요?', '건강'),
#  ('여름에 건강하게 지내려면 어떻게 해야 하나요? 알려주세요', '건강'),
#  ('암 안걸리고 건강하게 살고 싶습니다. 건강해지려면 어떻게 해야 하나요?', '건강'),
#  ('병에 걸려서 고생중입니다. 어떻게 하면 병이 낫고 건강해 질 수 있나요?', '건강'),
#  ('지금 만난 남자친구와 결혼해도 괜찮을까요?', '연애'),
#  ('연애하고 싶은데 어떤 사람을 만나야하나요? 궁금합니다.', '연애'),
#  ('연애한지 4년이 지났는데 한 번도 싸운적이 없습니다. 이 사람과 결혼해도 괜찮을까요?', '연애'),
#  ('결혼하고 싶은데 어떤 사람을 만나서 결혼해야하나요?', '연애'),
#  ('지금 좋아하는 사람이 있는데 고백해도 될까요? 이 사람과 결혼하고 싶어요.', '연애'),
#  ('제가 좋아하는 사람과 저를 좋아하는 사람 둘 중에 어떤 사람을 만나야 하나요?', '연애'),
#  ('오랜기간 만나서 정도 많이 들고 추억도 많이 쌓인 연인이랑 결혼해도 괜찮을까요?', '연애'),
#  ('제가 벌이가 좋지는 않은데 결혼하고 싶습니다. 결혼해도 괜찮을까요?', '연애'),
#  ('결혼 상대는 어떻게 결정해야하나요?', '연애'),
#  ('어떤 사람과 연애하고 결혼해야하나요? 좋은사람은 어떤 사람인가요?', '연애'),
#  ('어느 순간 나태함과 게으름으로 문제가 발생하고 있습니다.', '게으름'),
#  ('나태, 태만, 게으름을 고칠수있는 방법좀 알려주세요', '게으름'),
#  ('전 진짜로 게을러서 어렸을 때부터 집에서는 커녕 학원에서 2시간도 공부하지 못했습니다.', '게으름'),
#  ('점점 제가 나태해진것 같아요. 의욕이 없어졌죠. 의욕이 생기더라도 몇일 지나면 사그라졌어요 지금 벌써 3주 지났습니다', '게으름'),
#  ('대학생이 되니까 사람이 게으르고 나태해지는 걸 느낍니다. 어떻게 하면 사람이 좀 더 부지런해질 수 있을까요?', '게으름'),
#  ('게으름에서 벗어난 경험자분들의 조언이 필요합니다.', '게으름'),
#  ('제 자신이 너무 게을러서 싫습니다. 해야할 공부도 많고 읽을 책도 많은데 오히려 많아서인지 부담감 때문에 그냥 다 놓아버리고 싶어요.',
#   '게으름'),
#  ('게으름과 나태함으로 귀찮음을 느끼고 아무것도 안하는 제가 참 한심할 따름입니다. 어떻게 하면 게으름과 나태함을 고칠 수 있을까요?',
#   '게으름'),
#  ('저의 게으름과 모든걸 귀찮아하는 나태함을 치유할 방법이 없을까요', '게으름'),
#  ('매일 침대에서 일어나기가 싫습니다. 많이 게을러지고 나태해진 것 같습니다.', '게으름'),
#  ('겸손한 마음을 가지려면 어떻게해야되나요? 겸손하다의 뜻이 뭔가요?', '겸손'),
#  ('겸손 해지고 싶어요. 아직은 가진게 넉넉하지 않고 앞서 내세울 만큼 잘난 구석도 없구요. 보잘것 없고  부족 하지만 이 한몸 겸손한 맘으로 하나님만을 바라보며 늘 감사한 마음으로 살고 싶어요.',
#   '겸손'),
#  ('어떻게하면 좀 더 현명한 겸손한 사람이 될수 있을까요? 어떻게하면 남의 의견과 분야를 존중할수 있을까요?', '겸손'),
#  ('마음이 교만해질때 묵상할 수 있는 가장 좋은 말씀 좀 부탁합니다.', '겸손'),
#  ('진정한 겸손이란 무엇인가요?', '겸손'),
#  ('겸손은 말로 들으면 참 실천하기 좋은것 같아요 근데 막상하면 실천의지가 부족해서인지 너무 자만하는거같아요 겸손해지법좀 알려주세요',
#   '겸손'),
#  ('자만하지 않으려면 어떻게 해야하나요?  저는 자만해서 방심하다가 낭패를 자주 봅니다.', '겸손'),
#  ('착한 척 하는 사람이 아니라,  겸손한 척 하는 사람이 아니라  정말로 뼛 속까지 겸손한 사람이 되고 싶어요.', '겸손'),
#  ('교만하지 않고 마음이 겸손한 사람이 되고 싶은데 어떻게 해야 하나요?', '겸손'),
#  ('다른 사람을 존중하는 겸손한 사람이 되고 싶습니다. 교만을 버리고 싶습니다.', '겸손'),
#  ('기도를 하는법은 어떻게 되나요?', '기도'),
#  ('제가 교회를 다니는데 저만 방언을 안해서요 제가 평소에 기도도 잘 안해서 일까요?', '기도'),
#  ('교회를 다닌지 조금 오래 되지만 아직도 기도 하는 법를 잘 몰라서요. 기도는 어떻게 해야 하나요?', '기도'),
#  ('기도를 하고 싶은데 어떤 내용으로 기도를 해야하나요? 기도하면 응답을 받을 수 있나요?', '기도'),
#  ('기도할 때 구체적으로 무엇을 기도해야하는지 잘 모르겠습니다. 무엇에 대해서 기도해야하나요?', '기도'),
#  ('마음이 너무 복잡해서 기도가 되지 않습니다. 이럴 땐 어떻게 해야 하나요?', '기도'),
#  ('기도가 너무 어렵게 느껴지는데 기도는 어떻게 하는 건가요?', '기도'),
#  ('누군가를 위해서 기도하려는데 어떻게 기도해야하나요?', '기도'),
#  ('기도하는 것이 익숙하지 않고 교회를 다니지 않아서 기도하는 방법을 모르는데, 기도는 어떻게 하는 건가요?', '기도'),
#  ('기도에 집중이 잘 안되고 기도하면서 무슨 말을 해야하는지 잘 모르겠어요. 기도하는 방법에 대해서 알려주세요.', '기도'),
#  ('요즘 세상걱정에 잠을 못이루고 있습니다. 이런 저런 불안이 찾아오면서 너무 힘드네요.', '걱정'),
#  ('걱정이 너무 많아서 일이 손에 안잡힙니다. 틈만나면 이런 걱정 저런 걱정이 드는데 어떻게 하면 좋을까요?', '걱정'),
#  ('요즘들어서 쓸데없는 걱정을 많이 해서 힘듭니다. 너무 생각이 많습니다. 도대체 어떻게 해야 쓸데없는 생각들을 안할 수 있을까요?',
#   '걱정'),
#  ('제가 돈이 없어서 생활걱정에 시달리고 있습니다. 생활비에 대한 걱정을 안하려면 어떻게 해야 할까요?', '걱정'),
#  ('평소에 쓸데없는 걱정이 너무 많아서 힘듭니다. 걱정을 안하고 싶은데 어떻게 해야 할까요?', '걱정'),
#  ('일어나지도 않을 일들에 대해서 걱정도 되고 불안함에 두려움을 느끼기도 합니다. 어떻게 하면 두려움을 없앨 수 있을까요?', '걱정'),
#  ('제가 평소에 걱정과 염려가 많아서 일어나지도 않을 일에 두려움을 많이 느끼는데 어떻게 하면 좋을까요?', '걱정'),
#  ('걱정과 염려 때문에 힘듭니다. 어떻게 하면 걱정과 염려를 안할 수 있나요?', '걱정'),
#  ('계속 혼자 생각하고 걱정하고 불안해하고 하는데 어떻게 하면 염려를 없애고 두려워 하지 않을 수 있나요?', '걱정'),
#  ('기독교에서는 미래에 대한 걱정, 근심, 불안, 두려움이 있을때 어떻게 하나요?', '걱정'),
#  ('자꾸 지었던 죄를 반복해서 짓게 됩니다. 어떻게 하면 죄를 안지을 수 있나요?', '죄'),
#  ('제 동생이 죄를 지었습니다. 계속 반복해서 죄를 짓는데 어떻게 하면 좋나요?', '죄'),
#  ('사회가 점점 악해지고 범죄가 넘쳐나고 있습니다. 이 사회는 어떻게 죄에서 빠져 나올 수 있나요?', '죄'),
#  ('죄를 짓고 싶지 않은데 계속해서 죄를 짓게 됩니다. 어떻게 하면 좋을까요? 죄를 지었을 때는 어떻게 해야 하나요?', '죄'),
#  ('형제가 죄를 범한 것을 어떻게 하면 좋을까요? 죄를 용서해 주어야 하나요?', '죄'),
#  ('자매가 자꾸 죄를 짓는데 어떻게 하면 좋을까요? 죄를 지은 대가를 치르게 해야 하나요?', '죄'),
#  ('죄에서 벗어나고 싶은데 쉽지가 않습니다. 어떻게 하면 죄에서 벗어날 수 있나요? 죄를 짓지 않으려면 어떻게 살아야 하나요?', '죄'),
#  ('이 사회와 국가가 죄에 빠져 있는데 어떻게 하면 좋나요? 죄에서 자유를 얻게 하려면 어떻게 해야 할까요?', '죄'),
#  ('죄를 너무 많이 지었는데 저는 어떻게 되는 건가요? 죄를 해결 받기 위해서는 어떻게 해야 하나요?', '죄'),
#  ('죄를 범한사람을 어떻게 하면 좋을까요? 죄를 용서해줘야 할까요? 아니면 엄벌에 처해야 할까요?', '죄'),
#  ('일하면서 너무 지치고 힘들어요. 일하면서 일과 휴식의 균형은 어떻게 맞춰야 하나요?', '일'),
#  ('요새 일이 너무 바빠지면서 정신이 하나도 없습니다. 일을 이렇게 바쁘게만 하는게 맞나요?', '일'),
#  ('요새 일이 많아지면서 신앙이 뒷전이 되어가고 있습니다. 일과 신앙의 균형을 어떻게 맞춰야 하나요?', '일'),
#  ('일도 열심히 하고 신앙 생활도 열심히 하고 싶습니다. 어떻게 해야 하나요?', '일'),
#  ('일은 열심히 하려고 하는데 일에 성과가 나타나지 않습니다. 어떻게 하면 일의 성과를 만들 수 있나요?', '일'),
#  ('이제 곧 취업을 해야 하는데 어떤 직장에 다니는게 좋을까요? 또 어떤 마음가짐으로 직장에 임해야 할까요?', '일'),
#  ('이제 직장을 구해야 하는데 어떤 일을 해야할 지 잘 모르겠습니다. 어떤 직장을 선택하면 좋을까요?', '일'),
#  ('직장에서 일을 하는데 성과가 안나와서 매일 욕먹습니다. 어떻게 하면 좋은 결과를 얻어낼 수 있을까요?', '일'),
#  ('매일 일에 치이다보니 쉴 틈이 없습니다. 어떻게 하면 일과 쉼의 균형을 맞추어 갈 수 있나요?', '일'),
#  ('일을 열심히 하려하면 자꾸 신앙생활을 소홀히 하게 됩니다. 어떻게 하면 일과 신앙의 균형을 잘 맞출 수 있나요?', '일'),
#  ('진리는 무엇인가요? 어떻게 하면 진리에 대해서 알게 되나요?', '진리'),
#  ('진리에 대해서 알고 싶은데 어떻게 하면 알 수 있나요?', '진리'),
#  ('인생의 진리는 무엇일까요? 정말로 궁금합니다.', '진리'),
#  ('도대체 진리는 무엇인가요? 진리에 대해서 알고 싶습니다.', '진리'),
#  ('인생의 진리는 어디에 있나요? 진리를 깨닫게 되려면 어떻게 해야 하나요?', '진리'),
#  ('진리는 무엇인가요? 진리에 대해서 궁금함이 생겼는데 꼭 알고 싶습니다.', '진리'),
#  ('인생의 진리는 어디에서 찾을 수 있나요? 구체적으로 알려주세요.', '진리'),
#  ('모든것의 참 진리는 도대체 무엇인가요? 진리가 이 세상에 존재하기는 한 것인가요?', '진리'),
#  ('진리에 대해서 알고 싶습니다. 진리란 무엇인가요?', '진리'),
#  ('다들 진리에 대해서 얘기하는데 도대체 참 진리는 무엇인가요? 인생의 진리는 존재하는 것인가요?', '진리'),
#  ('인생이 너무 힘들고 고통스럽습니다. 고통속에서 매일매일 살고 있는데 어떻게 해야 하나요?', '고민')]

# %%
for record in sentence:
    twitter = Twitter()
    tpos = twitter.pos(record[0])
    s_t = []
    for t in tpos:
        if t[1] in pos_in and len(t[0]) > 2:
            if False == False : s_t.append(t[0])
            else : s_t.append(t[0]+'/'+t[1])
            
    words = s_t*1
    tagged.append(gensim.models.doc2vec.TaggedDocument(words,[record[1]]))
# Out:
# /Users/younghunjoo/opt/anaconda3/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
tagged
# Out:
# [TaggedDocument(words=['스트레스', '받아서', '힘들고', '고통스럽습니다', '어떻게', '하나요'], tags=['고통']),
#  TaggedDocument(words=['힘들고', '고통스러워요', '죽고싶다는', '어떻게', '해야하나요'], tags=['고통']),
#  TaggedDocument(words=['허우적거리고', '있는데', '어떻게', '하나요'], tags=['고통']),
#  TaggedDocument(words=['갑자기', '우울해지고', '어려워', '졌습니다', '어떻게', '살아내야하나요'], tags=['고통']),
#  TaggedDocument(words=[], tags=['고통']),
#  TaggedDocument(words=['하나님', '믿어도', '않습니다', '힘들고', '어려운데', '어떻게', '하나요'], tags=['고통']),
#  TaggedDocument(words=['힘들어', '있습니다', '덜어내려면', '어떻게', '하나요'], tags=['고통']),
#  TaggedDocument(words=['시달리고', '있습니다', '아파서', '나가지를', '합니다', '어떻게', '해야하나요'], tags=['고통']),
#  TaggedDocument(words=['입니다', '하려면', '어떻게', '해야하나요'], tags=['고통']),
#  TaggedDocument(words=['살면서', '했습니다', '어떻게', '있을까요'], tags=['고통']),
#  TaggedDocument(words=['안좋습니다', '건강해지려면', '어떻게', '하나요'], tags=['건강']),
#  TaggedDocument(words=['건강하게', '지내고', '싶습니다', '어떻게', '건강해질', '있나요'], tags=['건강']),
#  TaggedDocument(words=['안좋아서', '더부룩합니다', '건강해지려면', '어떻게', '해야하나요'], tags=['건강']),
#  TaggedDocument(words=['있을까요'], tags=['건강']),
#  TaggedDocument(words=['환절기', '알려주세요'], tags=['건강']),
#  TaggedDocument(words=['많은데', '건강해지고', '싶습니다', '건강해지려면', '어떻게', '해야하나요'], tags=['건강']),
#  TaggedDocument(words=['같아서', '하려고', '합니다', '어떻게', '좋을까요'], tags=['건강']),
#  TaggedDocument(words=['건강하게', '지내려면', '어떻게', '하나요', '알려주세요'], tags=['건강']),
#  TaggedDocument(words=['걸리고', '건강하게', '싶습니다', '건강해지려면', '어떻게', '하나요'], tags=['건강']),
#  TaggedDocument(words=['걸려서', '입니다', '어떻게', '건강해', '있나요'], tags=['건강']),
#  TaggedDocument(words=['남자친구', '괜찮을까요'], tags=['연애']),
#  TaggedDocument(words=['싶은데', '만나야하나요', '궁금합니다'], tags=['연애']),
#  TaggedDocument(words=['지났는데', '없습니다', '사람과', '괜찮을까요'], tags=['연애']),
#  TaggedDocument(words=['싶은데', '만나서', '해야하나요'], tags=['연애']),
#  TaggedDocument(words=['좋아하는', '있는데', '사람과', '싶어요'], tags=['연애']),
#  TaggedDocument(words=['좋아하는', '사람과', '좋아하는', '만나야', '하나요'], tags=['연애']),
#  TaggedDocument(words=['만나서', '괜찮을까요'], tags=['연애']),
#  TaggedDocument(words=['좋지는', '않은데', '싶습니다', '괜찮을까요'], tags=['연애']),
#  TaggedDocument(words=['어떻게', '해야하나요'], tags=['연애']),
#  TaggedDocument(words=['사람과', '해야하나요'], tags=['연애']),
#  TaggedDocument(words=['나태함과', '게으름', '있습니다'], tags=['게으름']),
#  TaggedDocument(words=['게으름', '고칠수있는', '알려주세요'], tags=['게으름']),
#  TaggedDocument(words=['게을러서', '어렸을', '했습니다'], tags=['게으름']),
#  TaggedDocument(words=['나태해진것', '같아요', '없어졌죠', '생기더라도', '지나면', '사그라졌어요', '지났습니다'], tags=['게으름']),
#  TaggedDocument(words=['대학생', '되니까', '게으르고', '나태해지는', '느낍니다', '어떻게', '부지런해질', '있을까요'], tags=['게으름']),
#  TaggedDocument(words=['게으름', '벗어난', '필요합니다'], tags=['게으름']),
#  TaggedDocument(words=['게을러서', '싫습니다', '많은데', '오히려', '많아서', '버리고', '싶어요'], tags=['게으름']),
#  TaggedDocument(words=['게으름', '나태함으로', '느끼고', '한심할', '입니다', '어떻게', '게으름', '나태함을', '있을까요'], tags=['게으름']),
#  TaggedDocument(words=['게으름', '귀찮아하는', '나태함을', '없을까요'], tags=['게으름']),
#  TaggedDocument(words=['일어나기가', '싫습니다', '게을러지고', '나태해진', '같습니다'], tags=['게으름']),
#  TaggedDocument(words=['겸손한', '가지려면', '어떻게', '되나요', '겸손하다의'], tags=['겸손']),
#  TaggedDocument(words=['싶어요', '가진게', '넉넉하지', '내세울', '없구요', '겸손한', '하나님', '바라보며', '감사한', '싶어요'], tags=['겸손']),
#  TaggedDocument(words=['현명한', '겸손한', '있을까요', '있을까요'], tags=['겸손']),
#  TaggedDocument(words=['교만해질', '합니다'], tags=['겸손']),
#  TaggedDocument(words=['진정한'], tags=['겸손']),
#  TaggedDocument(words=['들으면', '같아요', '부족해서인지', '자만하는거', '같아요', '겸손해', '알려주세요'], tags=['겸손']),
#  TaggedDocument(words=['자만하지', '않으려면', '어떻게', '해야하나요', '자만해서', '방심하다가', '봅니다'], tags=['겸손']),
#  TaggedDocument(words=['아니라', '겸손한', '아니라', '겸손한', '싶어요'], tags=['겸손']),
#  TaggedDocument(words=['교만하지', '겸손한', '싶은데', '어떻게', '하나요'], tags=['겸손']),
#  TaggedDocument(words=['겸손한', '싶습니다', '버리고', '싶습니다'], tags=['겸손']),
#  TaggedDocument(words=['어떻게', '되나요'], tags=['기도']),
#  TaggedDocument(words=['다니는데', '해서요'], tags=['기도']),
#  TaggedDocument(words=['다닌지', '되지만', '몰라서요', '어떻게', '하나요'], tags=['기도']),
#  TaggedDocument(words=['싶은데', '해야하나요', '있나요'], tags=['기도']),
#  TaggedDocument(words=['해야하는지', '모르겠습니다', '해야하나요'], tags=['기도']),
#  TaggedDocument(words=['복잡해서', '않습니다', '어떻게', '하나요'], tags=['기도']),
#  TaggedDocument(words=['어렵게', '느껴지는데', '어떻게'], tags=['기도']),
#  TaggedDocument(words=['누군가', '하려는데', '어떻게', '해야하나요'], tags=['기도']),
#  TaggedDocument(words=['익숙하지', '다니지', '않아서', '모르는데', '어떻게'], tags=['기도']),
#  TaggedDocument(words=['안되고', '하면서', '해야하는지', '모르겠어요', '알려주세요'], tags=['기도']),
#  TaggedDocument(words=['이루고', '있습니다', '찾아오면서', '힘드네요'], tags=['걱정']),
#  TaggedDocument(words=['많아서', '잡힙니다', '만나면', '드는데', '어떻게', '좋을까요'], tags=['걱정']),
#  TaggedDocument(words=['들어서', '쓸데없는', '힘듭니다', '많습니다', '도대체', '어떻게', '쓸데없는', '있을까요'], tags=['걱정']),
#  TaggedDocument(words=['없어서', '시달리고', '있습니다', '생활비', '하려면', '어떻게'], tags=['걱정']),
#  TaggedDocument(words=['쓸데없는', '많아서', '힘듭니다', '싶은데', '어떻게'], tags=['걱정']),
#  TaggedDocument(words=['일어나지', '불안함에', '두려움', '합니다', '어떻게', '두려움', '있을까요'], tags=['걱정']),
#  TaggedDocument(words=['많아서', '일어나지', '두려움', '느끼는데', '어떻게', '좋을까요'], tags=['걱정']),
#  TaggedDocument(words=['힘듭니다', '어떻게', '있나요'], tags=['걱정']),
#  TaggedDocument(words=['불안해하고', '하는데', '어떻게', '없애고', '두려워', '있나요'], tags=['걱정']),
#  TaggedDocument(words=['기독교', '두려움', '어떻게', '하나요'], tags=['걱정']),
#  TaggedDocument(words=['지었던', '됩니다', '어떻게', '안지을', '있나요'], tags=['죄']),
#  TaggedDocument(words=['지었습니다', '짓는데', '어떻게', '좋나요'], tags=['죄']),
#  TaggedDocument(words=['악해지고', '넘쳐나고', '있습니다', '어떻게', '있나요'], tags=['죄']),
#  TaggedDocument(words=['않은데', '됩니다', '어떻게', '좋을까요', '지었을', '어떻게', '하나요'], tags=['죄']),
#  TaggedDocument(words=['어떻게', '좋을까요', '하나요'], tags=['죄']),
#  TaggedDocument(words=['짓는데', '어떻게', '좋을까요', '치르게', '하나요'], tags=['죄']),
#  TaggedDocument(words=['벗어나고', '싶은데', '쉽지가', '않습니다', '어떻게', '벗어날', '있나요', '않으려면', '어떻게', '살아야', '하나요'], tags=['죄']),
#  TaggedDocument(words=['있는데', '어떻게', '좋나요', '하려면', '어떻게'], tags=['죄']),
#  TaggedDocument(words=['지었는데', '어떻게', '해서는', '어떻게', '하나요'], tags=['죄']),
#  TaggedDocument(words=['어떻게', '좋을까요', '해줘야', '아니면'], tags=['죄']),
#  TaggedDocument(words=['하면서', '지치고', '힘들어요', '하면서', '어떻게', '맞춰야', '하나요'], tags=['일']),
#  TaggedDocument(words=['바빠지면서', '없습니다', '바쁘게만', '하는게', '맞나요'], tags=['일']),
#  TaggedDocument(words=['많아지면서', '되어가고', '있습니다', '어떻게', '맞춰야', '하나요'], tags=['일']),
#  TaggedDocument(words=['싶습니다', '어떻게', '하나요'], tags=['일']),
#  TaggedDocument(words=['하려고', '하는데', '나타나지', '않습니다', '어떻게', '있나요'], tags=['일']),
#  TaggedDocument(words=['하는데', '다니는게', '좋을까요', '마음가짐'], tags=['일']),
#  TaggedDocument(words=['하는데', '모르겠습니다', '좋을까요'], tags=['일']),
#  TaggedDocument(words=['하는데', '나와서', '욕먹습니다', '어떻게', '있을까요'], tags=['일']),
#  TaggedDocument(words=['없습니다', '어떻게', '맞추어', '있나요'], tags=['일']),
#  TaggedDocument(words=['하려하면', '소홀히', '됩니다', '어떻게', '있나요'], tags=['일']),
#  TaggedDocument(words=['어떻게', '되나요'], tags=['진리']),
#  TaggedDocument(words=['싶은데', '어떻게', '있나요'], tags=['진리']),
#  TaggedDocument(words=['궁금합니다'], tags=['진리']),
#  TaggedDocument(words=['도대체', '싶습니다'], tags=['진리']),
#  TaggedDocument(words=['있나요', '깨닫게', '되려면', '어떻게', '하나요'], tags=['진리']),
#  TaggedDocument(words=['궁금함이', '생겼는데', '싶습니다'], tags=['진리']),
#  TaggedDocument(words=['있나요', '알려주세요'], tags=['진리']),
#  TaggedDocument(words=['도대체', '하기는'], tags=['진리']),
#  TaggedDocument(words=['싶습니다', '진리란'], tags=['진리']),
#  TaggedDocument(words=['하는데', '도대체'], tags=['진리']),
#  TaggedDocument(words=['힘들고', '고통스럽습니다', '있는데', '어떻게', '하나요'], tags=['고민'])]

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=10, window=3, min_count=3, epochs=1, workers=10)

# %%
model.build_vocab(tagged)

# %%
model.train(tagged, total_examples=model.corpus_count, epochs=model.epochs)

# %%
n = len(model.docvecs)
UrlScore = model.docvecs.most_similar("고민", topn=10)

# %%
UrlScore[:3]
# Out:
# [('건강', 0.29680773615837097),
#  ('죄', 0.29373955726623535),
#  ('기도', 0.11012309789657593)]
